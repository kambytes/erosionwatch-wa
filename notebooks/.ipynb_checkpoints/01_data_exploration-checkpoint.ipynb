# %% [markdown]
# Data exploration of DOT18,19 and 20 datasets.

# %% [markdown]
# Connected to DataWA's WFS. Identified the relavant dataset names for DOT18, 19 and 20.

# %%
# imports
from owslib.wfs import WebFeatureService
import requests
import geopandas as gpd
from io import BytesIO

# %% [markdown]
# Create a WFS object first with the URL.

# %%
WFS_URL = "https://public-services.slip.wa.gov.au/public/services/SLIP_Public_Services/Infrastructure_and_Utilities_WFS/MapServer/WFSServer"

wfs = WebFeatureService(url=WFS_URL, version='2.0.0')

# %% [markdown]
# Next, we need to explore the metadata of the WFS service offered by DataWA. We will also see the operations available for us to use.

# %%
print(wfs.identification.type)
print(wfs.identification.version)
print(wfs.identification.title)
print(wfs.identification.abstract)

operations = []
for i in wfs.operations:
    operations.append(i)
operations
# Out:
# WFS
# 2.0.0
# WFS
# None
# [<owslib.ows.OperationsMetadata GetCapabilities at 0x114a7e190>,
#  <owslib.ows.OperationsMetadata DescribeFeatureType at 0x114a7e120>,
#  <owslib.ows.OperationsMetadata GetPropertyValue at 0x114a7e510>,
#  <owslib.ows.OperationsMetadata GetFeature at 0x114a7e580>,
#  <owslib.ows.OperationsMetadata GetGmlObject at 0x114a7e2e0>,
#  <owslib.ows.OperationsMetadata ListStoredQueries at 0x114a7e040>,
#  <owslib.ows.OperationsMetadata DescribeStoredQueries at 0x114a7e200>,
#  <owslib.ows.OperationsMetadata ImplementsBasicWFS at 0x114a7cde0>,
#  <owslib.ows.OperationsMetadata ImplementsTransactionalWFS at 0x114a7d9b0>,
#  <owslib.ows.OperationsMetadata ImplementsLockingWFS at 0x114a7e350>,
#  <owslib.ows.OperationsMetadata KVPEncoding at 0x114a7e3c0>,
#  <owslib.ows.OperationsMetadata XMLEncoding at 0x114a7e430>,
#  <owslib.ows.OperationsMetadata SOAPEncoding at 0x114a7e4a0>,
#  <owslib.ows.OperationsMetadata ImplementsInheritance at 0x114a7e5f0>,
#  <owslib.ows.OperationsMetadata ImplementsRemoteResolve at 0x114a7e660>,
#  <owslib.ows.OperationsMetadata ImplementsResultPaging at 0x114a7e6d0>,
#  <owslib.ows.OperationsMetadata ImplementsStandardJoins at 0x114a7e740>,
#  <owslib.ows.OperationsMetadata ImplementsSpatialJoins at 0x114a7e7b0>,
#  <owslib.ows.OperationsMetadata ImplementsTemporalJoins at 0x114a7e820>,
#  <owslib.ows.OperationsMetadata ImplementsFeatureVersioning at 0x114a7e900>,
#  <owslib.ows.OperationsMetadata ManageStoredQueries at 0x114a7e9e0>,
#  <owslib.ows.OperationsMetadata CountDefault at 0x114a7e890>]

# %%
#what are the output formats available for getfeature request? This is our download options 
wfs.getOperationByName('GetFeature').parameters
# Out:
# {'resultType': {'values': ['results', 'hits']},
#  'outputFormat': {'values': ['GML32',
#    'GML32+ZIP',
#    'GML32+GZIP',
#    'application/gml+xml; version=3.2',
#    'GML3',
#    'GML3+ZIP',
#    'GML3+GZIP',
#    'text/xml; subtype=gml/3.1.1',
#    'GML2',
#    'GML2+ZIP',
#    'GML2+GZIP',
#    'text/xml; subtype=gml/2.1.2',
#    'GEOJSON',
#    'GEOJSON+ZIP',
#    'GEOJSON+GZIP',
#    'ESRIGEOJSON',
#    'ESRIGEOJSON+ZIP',
#    'ESRIGEOJSON+GZIP',
#    'KML',
#    'application/vnd.google-earth.kml xml',
#    'application/vnd.google-earth.kml+xml',
#    'KMZ',
#    'application/vnd.google-earth.kmz',
#    'SHAPE+ZIP',
#    'CSV',
#    'CSV+ZIP',
#    'CSV+GZIP',
#    'Geopackage',
#    'Geopackage+ZIP']},
#  'resolve': {'values': ['none', 'local']}}

# %%
for dataset in wfs.contents:
    print(dataset)
# Will help us investigate and identify dataset layer names of DOT18,19 and 20.
# esri:Coastal_Infrastructure_Point__DOT-018_
# esri:Coastal_Infrastructure_Line__DOT-019_
# esri:Coastal_Infrastructure_DOT__DOT-020_
# Out:
# esri:Water_Meter__WCORP-006_
# esri:Water_Valve__WCORP-299_
# esri:Water_Pipe__WCORP-002_
# esri:Harvey_Water_Irrigation_Districts__HARWA-002_
# esri:Harvey_Water_Pipelines__HARWA-001_
# esri:Harvey_Water_Additional_Works__HARWA-004_
# esri:DFES_Stations__DFES-023_
# esri:Sewer_Manhole__WCORP-026_
# esri:Drain_Manhole__WCORP-291_
# esri:Water_Hydrant__WCORP-070_
# esri:Water_Standpipe__WCORP-071_
# esri:Water_Treatment_Plant__WCORP-072_
# esri:Water_Bore__WCORP-073_
# esri:Water_Tank__WCORP-076_
# esri:Water_Pump_Station__WCORP-077_
# esri:Drainage_Observation_Bore__WCORP-081_
# esri:Drainage_Pump_Station__WCORP-082_
# esri:Sewer_Pump_Station__WCORP-295_
# esri:Sewer_Treatment_Plant__WCORP-296_
# esri:Coastal_Infrastructure_Point__DOT-018_
# esri:Sewer_Gravity_Pipe__WCORP-068_
# esri:Sewer_Pressure_Main__WCORP-069_
# esri:Drainage_Rising_Main__WCORP-074_
# esri:Drainage_Gravity_Pipe__WCORP-080_
# esri:Drainage_Open_Channel__WCORP-083_
# esri:Drain_Inlet__WCORP-290_
# esri:Irrigation_Gravity_Pipe__WCORP-292_
# esri:Irrigation_Open_Channel__WCORP-293_
# esri:Sewer_Connection__WCORP-084_
# esri:Coastal_Infrastructure_Line__DOT-019_
# esri:Sewer_Treatment_Pond__WCORP-297_
# esri:Water_Dam__WCORP-075_
# esri:Water_Reservoir__WCORP-078_
# esri:Drainage_Compensating_Basin__WCORP-079_
# esri:Water_Storage_Complex__WCORP-298_
# esri:Irrigation_Dams__WCORP-294_
# esri:Buffer_Areas__WCORP-088_
# esri:Water_Buffer_Areas__WCORP-244_
# esri:Drainage_Nodes_Wanneroo__WAN-002_
# esri:Drainage_Pipes_Wanneroo__WAN-001_
# esri:WaterCorp_CIP_Planned_Assets_Water_Points_WCORP__WCORP-010_
# esri:WaterCorp_CIP_Planned_Assets_Waste_Water_Points_WCORP__WCORP-011_
# esri:WaterCorp_CIP_Planned_Assets_Drainage__Points__WCORP__WCORP-012_
# esri:WaterCorp_CIP_Planned_Assets_Water__Lines__WCORP__WCORP-013_
# esri:WaterCorp_CIP_Planned_Assets_Waste_Water__Lines__WCORP__WCORP-014_
# esri:WaterCorp_CIP_Planned_Assets_Drainage__Lines__WCORP__WCORP-015_
# esri:Coastal_Infrastructure_Projects__DOT-027_
# esri:Coastal_Infrastructure_DOT__DOT-020_
# esri:Public_Boat_Ramps__DOT-033_
# esri:Water_Corporation_Regions__WCORP-322_
# esri:Water_Corporation_Districts__WCORP-323_
# esri:Water_Corporation_Licenced_Operating_Areas__WCORP-324_

# %% [markdown]
# Next, let us investigate the individual datasets to identify the type of structures present in each dataset. To do so, I have to first download the datasets and save as geojson files.

# %%
layer_names = ["esri:Coastal_Infrastructure_Point__DOT-018_", "esri:Coastal_Infrastructure_Line__DOT-019_", "esri:Coastal_Infrastructure_DOT__DOT-020_"]
print(wfs.contents[layer_names[0]].title)
wfs.get_schema(layer_names[0])
# Out:
# Coastal_Infrastructure_Point__DOT-018_
# {'properties': {'objectid': 'int',
#   'agencyid': 'double',
#   'agencyname': 'string',
#   'structype': 'string',
#   'assetgroup': 'string',
#   'assetcode': 'string',
#   'assetdesc': 'string',
#   'lga': 'string',
#   'portauth': 'string',
#   'sourcedate': 'dateTime',
#   'source': 'string',
#   'conmat': 'string',
#   'constrdate': 'dateTime',
#   'status': 'string',
#   'editdate': 'dateTime',
#   'techdraw': 'string',
#   'refcomm': 'string',
#   'reflink': 'string',
#   'ci_id': 'string',
#   'SourceDate_txt': 'string',
#   'EditDate_txt': 'string'},
#  'required': ['objectid'],
#  'geometry': 'Point',
#  'geometry_column': 'shape'}

# %%
print(wfs.contents[layer_names[1]].title)
wfs.get_schema(layer_names[1])
# Out:
# Coastal_Infrastructure_Line__DOT-019_
# {'properties': {'objectid': 'int',
#   'agencyid': 'double',
#   'agencyname': 'string',
#   'structype': 'string',
#   'assetgroup': 'string',
#   'assetcode': 'string',
#   'assetdesc': 'string',
#   'lga': 'string',
#   'portauth': 'string',
#   'sourcedate': 'dateTime',
#   'source': 'string',
#   'conmat': 'string',
#   'constrdate': 'dateTime',
#   'status': 'string',
#   'editdate': 'dateTime',
#   'techdraw': 'string',
#   'refcomm': 'string',
#   'reflink': 'string',
#   'ci_id': 'string',
#   'SourceDate_txt': 'string',
#   'EditDate_txt': 'string'},
#  'required': ['objectid'],
#  'geometry': None}

# %%
print(wfs.contents[layer_names[0]].title)
wfs.get_schema(layer_names[2])
# Out:
# Coastal_Infrastructure_Point__DOT-018_
# {'properties': {'objectid': 'int',
#   'agencyid': 'double',
#   'agencyname': 'string',
#   'structype': 'string',
#   'assetgroup': 'string',
#   'assetcode': 'string',
#   'assetdesc': 'string',
#   'lga': 'string',
#   'portauth': 'string',
#   'sourcedate': 'dateTime',
#   'source': 'string',
#   'conmat': 'string',
#   'constrdate': 'dateTime',
#   'status': 'string',
#   'editdate': 'dateTime',
#   'techdraw': 'string',
#   'refcomm': 'string',
#   'reflink': 'string',
#   'ci_id': 'string',
#   'SourceDate_txt': 'string',
#   'EditDate_txt': 'string',
#   'st_perimeter_shape_': 'double'},
#  'required': ['objectid', 'st_perimeter_shape_'],
#  'geometry': '3D MultiPolygon',
#  'geometry_column': 'shape'}

# %% [markdown]
# Next, as we have completed exploring the metadata related information of each dataset, we can now save them into geojson files.

# %%
# function to fetch + save + load
def fetch_and_save(layer_name):
    print(f"\nFetching {layer_name}...")

    response = wfs.getfeature(
        typename=layer_name,
        outputFormat='GEOJSON' 
    )

    file_path = f"../data/raw/{layer_name.replace(':', '_')}.geojson"

    # save raw file
    with open(file_path, 'wb') as f:
        f.write(response.read())

    response.close()

    print(f"Saved → {file_path}")

    # load into GeoDataFrame
    gdf = gpd.read_file(file_path)

    print(f"Loaded {len(gdf)} features")
    print(f"CRS: {gdf.crs}")
    print(f"Geometry types: {gdf.geometry.geom_type.unique()}")

    return gdf


# fetch all datasets
datasets = {}

for layer in layer_names:
    datasets[layer] = fetch_and_save(layer)


# assign for convenience
dot18 = datasets['esri:Coastal_Infrastructure_Point__DOT-018_']
dot19 = datasets['esri:Coastal_Infrastructure_Line__DOT-019_']
dot20 = datasets['esri:Coastal_Infrastructure_DOT__DOT-020_']
# Out:
# Fetching esri:Coastal_Infrastructure_Point__DOT-018_...
# Saved → ../data/raw/esri_Coastal_Infrastructure_Point__DOT-018_.geojson
# Loaded 5981 features
# CRS: EPSG:4326
# Geometry types: <StringArray>
# ['Point']
# Length: 1, dtype: str
#
# Fetching esri:Coastal_Infrastructure_Line__DOT-019_...
# Saved → ../data/raw/esri_Coastal_Infrastructure_Line__DOT-019_.geojson
# Loaded 50 features
# CRS: EPSG:4326
# Geometry types: [None]
#
# Fetching esri:Coastal_Infrastructure_DOT__DOT-020_...
# Saved → ../data/raw/esri_Coastal_Infrastructure_DOT__DOT-020_.geojson
# Loaded 8535 features
# CRS: EPSG:4326
# Geometry types: <StringArray>
# ['MultiPolygon']
# Length: 1, dtype: str

# %%
# initial data exploration
print(dot18.head)
print(dot18.columns)
print(dot18.dtypes)


#checking validity of datasets and if all values are correct/are present with no errors.
print(dot18.geometry.geom_type.value_counts())
print(dot18.geometry.is_valid.value_counts())
print(dot18.geometry.is_empty.sum())
# Out:
# <bound method NDFrame.head of                                             GmlID  objectid  agencyid  \
# 0        Coastal_Infrastructure_Point__DOT-018_.1         1       NaN
# 1        Coastal_Infrastructure_Point__DOT-018_.2         2       NaN
# 2        Coastal_Infrastructure_Point__DOT-018_.3         3       NaN
# 3        Coastal_Infrastructure_Point__DOT-018_.4         4       NaN
# 4        Coastal_Infrastructure_Point__DOT-018_.5         5       NaN
# ...                                           ...       ...       ...
# 5976  Coastal_Infrastructure_Point__DOT-018_.5977      5977       NaN
# 5977  Coastal_Infrastructure_Point__DOT-018_.5978      5978       NaN
# 5978  Coastal_Infrastructure_Point__DOT-018_.5979      5979       NaN
# 5979  Coastal_Infrastructure_Point__DOT-018_.5980      5980       NaN
# 5980  Coastal_Infrastructure_Point__DOT-018_.5981      5981       NaN
#
#      agencyname structype assetgroup assetcode  \
# 0          null       MRP         MR        MR
# 1          null       MRP         MR        MR
# 2          null       MRP         MR        MR
# 3          null       MRP         MR        MR
# 4          null       MRP         MR        MR
# ...         ...       ...        ...       ...
# 5976       null       MRP         MR        MR
# 5977       null       MRP         MR        MR
# 5978       null       MRP         MR        MR
# 5979       null       MRP         MR        MR
# 5980       null       MRP         MR        MR
#
#                                               assetdesc  \
# 0                                       Success Harbour
# 1                                       Success Harbour
# 2                                       Success Harbour
# 3                                       Success Harbour
# 4                                       Success Harbour
# ...                                                 ...
# 5976  Pen Landing - SYC (3rd from West) - East Frema...
# 5977  Pen Landing - SYC (2nd from West) - East Frema...
# 5978  Pen Landing - SYC (2nd from West) - East Frema...
# 5979  Pen Landing - SYC (2nd from West) - East Frema...
# 5980  Pen Landing - SYC (2nd from West) - East Frema...
#
#                           lga portauth  ... constrdate    status  editdate  \
# 0          Fremantle, City of     null  ...       null  Existing  1/6/2014
# 1          Fremantle, City of     null  ...       null  Existing  1/6/2014
# 2          Fremantle, City of     null  ...       null  Existing  1/6/2014
# 3          Fremantle, City of     null  ...       null  Existing  1/6/2014
# 4          Fremantle, City of     null  ...       null  Existing  1/6/2014
# ...                       ...      ...  ...        ...       ...       ...
# 5976  East Fremantle, Town of     null  ...       null  Existing  1/8/2014
# 5977  East Fremantle, Town of     null  ...       null  Existing  1/8/2014
# 5978  East Fremantle, Town of     null  ...       null  Existing  1/8/2014
# 5979  East Fremantle, Town of     null  ...       null  Existing  1/8/2014
# 5980  East Fremantle, Town of     null  ...       null  Existing  1/8/2014
#
#      techdraw refcomm reflink    ci_id SourceDate_txt EditDate_txt  \
# 0        null    null    null  PT04800      1/01/2013    6/01/2014
# 1        null    null    null  PT04801      1/01/2013    6/01/2014
# 2        null    null    null  PT04802      1/01/2013    6/01/2014
# 3        null    null    null  PT04803      1/01/2013    6/01/2014
# 4        null    null    null  PT04804      1/01/2013    6/01/2014
# ...       ...     ...     ...      ...            ...          ...
# 5976     null    null    null  PT01621      1/01/2013    8/01/2014
# 5977     null    null    null  PT01622      1/01/2013    8/01/2014
# 5978     null    null    null  PT01623      1/01/2013    8/01/2014
# 5979     null    null    null  PT01624      1/01/2013    8/01/2014
# 5980     null    null    null  PT01625      1/01/2013    8/01/2014
#
#                          geometry
# 0     POINT (115.74704 -32.06812)
# 1     POINT (115.74709 -32.06808)
# 2     POINT (115.74708 -32.06816)
# 3     POINT (115.74713 -32.06812)
# 4      POINT (115.74712 -32.0682)
# ...                           ...
# 5976  POINT (115.76261 -32.02653)
# 5977   POINT (115.76232 -32.0266)
# 5978  POINT (115.76234 -32.02658)
# 5979  POINT (115.76235 -32.02655)
# 5980  POINT (115.76237 -32.02651)
#
# [5981 rows x 23 columns]>
# Index(['GmlID', 'objectid', 'agencyid', 'agencyname', 'structype',
#        'assetgroup', 'assetcode', 'assetdesc', 'lga', 'portauth', 'sourcedate',
#        'source', 'conmat', 'constrdate', 'status', 'editdate', 'techdraw',
#        'refcomm', 'reflink', 'ci_id', 'SourceDate_txt', 'EditDate_txt',
#        'geometry'],
#       dtype='str')
# GmlID                  str
# objectid             int32
# agencyid           float64
# agencyname             str
# structype              str
# assetgroup             str
# assetcode              str
# assetdesc              str
# lga                    str
# portauth               str
# sourcedate             str
# source                 str
# conmat                 str
# constrdate             str
# status                 str
# editdate               str
# techdraw               str
# refcomm                str
# reflink                str
# ci_id                  str
# SourceDate_txt         str
# EditDate_txt           str
# geometry          geometry
# dtype: object
# Point    5981
# Name: count, dtype: int64
# True    5981
# Name: count, dtype: int64
# 0

# %%
print(dot18.crs)
print(dot19.crs)
print(dot20.crs)
# all datasets are in same coordinate system. As CRS is in EPSG:4326, we need to reproject to another coordinate system.
# Out:
# EPSG:4326
# EPSG:4326
# EPSG:4326
